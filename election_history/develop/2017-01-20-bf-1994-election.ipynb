# %%
import requests
from bs4 import BeautifulSoup as BS 

import sys
sys.path.append('..')

from src.utils import postals

# %%
url_parent = 'http://www.tse.jus.br/eleicoes/eleicoes-anteriores/eleicoes-1994/resultados-das-eleicoes-1994'

# %%
r = requests.get(url_parent)
soup = BS(r.text, 'html.parser')

# %%
from collections import namedtuple
Resultado = namedtuple('Resultado', ['UF', 'data'])

# %%
hrefs = soup.select('tr.tabelas a')
hrefs = [(list(a.strings)[0], a.attrs['href']) for a in hrefs]
hrefs = [Resultado(postals[uf], href) for uf, href in hrefs if uf != 'Brasil']

# %%
print('Pegando página de resultados...')
hrefs_results = []
for uf, href in hrefs:
    r = requests.get(href)
    soup = BS(r.text, 'html.parser')
    print(uf)
    url_results = soup.find(text='Presidente').parent.attrs['href']

    hrefs_results.append(Resultado(uf, url_results))
# Out:
# Pegando página de resultados...
# AC
# MA
# RJ
# AL
# MG
# RN
# AM
# MS
# RS
# AP
# MT
# RO
# BA
# PA
# RR
# CE
# PB
# SC
# DF
# PR
# SE
# ES
# PE
# SP
# GO
# PI
# TO

# %%
print('Pegando Tabelas...')
tables_results = []
for uf, href in hrefs_results:
    r = requests.get(href)
    soup = BS(r.text, 'html.parser')
    print(uf)
    table = soup.select('table')[0]
    
    tables_results.append(Resultado(uf, table))
# Out:
# Pegando Tabelas...
# AC
# MA
# RJ
# AL
# MG
# RN
# AM
# MS
# RS
# AP
# MT
# RO
# BA
# PA
# RR
# CE
# PB
# SC
# DF
# PR
# SE
# ES
# PE
# SP
# GO
# PI
# TO

# %%
def structure_table(table):
    structured = []
    rows = table.data.select('tr')

    while len(rows[0].select('th')) == 0:
        del rows[0]

    header, data = rows[0], rows[1:]
    header = [
        'NUM_TURNO',
        'SIGLA_UF',
        'NOME_CANDIDATO',
        'SIGLA_PARTIDO',
        'TOTAL_VOTOS',
        'VALIDOS'
    ]

    structured.append(header)
    for dr in data:
        structured.append([1, table.UF] + [next(td.strings) for td in dr.select('td')])

    return structured

# %%
tables = [structure_table(table) for table in tables_results]

# %%
import pandas as pd

# %%
df = pd.concat((pd.DataFrame(table[1:], columns=table[0]) for table in tables), ignore_index=True)

# %%
df.NOME_CANDIDATO = df.NOME_CANDIDATO.str.slice(3)

# %%
df = df.drop('VALIDOS', axis=1)
# Out:
#      NUM_TURNO SIGLA_UF               NOME_CANDIDATO SIGLA_PARTIDO TOTAL_VOTOS
# 0            1       AC    FERNANDO HENRIQUE CARDOSO          PSDB      90.132
# 1            1       AC    LUIZ INACIO LULA DA SILVA            PT      39.656
# 2            1       AC              ORESTES QUERCIA          PMDB      17.708
# 3            1       AC      ENEAS FERREIRA CARNEIRO         PRONA      12.636
# 4            1       AC      LEONEL DE MOURA BRIZOLA           PDT       2.238
# 5            1       AC  ESPERIDIAO AMIN HELOU FILHO           PPR       2.121
# 6            1       AC         CARLOS ANTONIO GOMES           PRN       1.640
# 7            1       AC      HERNANI GOULART FORTUNA           PSC         754
# 8            1       MA    FERNANDO HENRIQUE CARDOSO          PSDB     785.417
# 9            1       MA    LUIZ INACIO LULA DA SILVA            PT     292.057
# 10           1       MA      ENEAS FERREIRA CARNEIRO         PRONA      72.687
# 11           1       MA              ORESTES QUERCIA          PMDB      48.771
# 12           1       MA      LEONEL DE MOURA BRIZOLA           PDT      21.191
# 13           1       MA  ESPERIDIAO AMIN HELOU FILHO           PPR      17.503
# 14           1       MA         CARLOS ANTONIO GOMES           PRN      17.343
# 15           1       MA      HERNANI GOULART FORTUNA           PSC       6.746
# 16           1       RJ    FERNANDO HENRIQUE CARDOSO          PSDB   3.102.664
# 17           1       RJ    LUIZ INACIO LULA DA SILVA            PT   1.689.772
# 18           1       RJ      ENEAS FERREIRA CARNEIRO         PRONA     767.702
# 19           1       RJ      LEONEL DE MOURA BRIZOLA           PDT     702.182
# 20           1       RJ              ORESTES QUERCIA          PMDB     152.738
# 21           1       RJ  ESPERIDIAO AMIN HELOU FILHO           PPR      91.575
# 22           1       RJ      HERNANI GOULART FORTUNA           PSC      39.422
# 23           1       RJ         CARLOS ANTONIO GOMES           PRN      30.253
# 24           1       AL    FERNANDO HENRIQUE CARDOSO          PSDB     525.036
# 25           1       AL    LUIZ INACIO LULA DA SILVA            PT      84.929
# 26           1       AL      ENEAS FERREIRA CARNEIRO         PRONA      31.131
# 27           1       AL              ORESTES QUERCIA          PMDB      24.675
# 28           1       AL         CARLOS ANTONIO GOMES           PRN       6.882
# 29           1       AL  ESPERIDIAO AMIN HELOU FILHO           PPR       6.615
# ..         ...      ...                          ...           ...         ...
# 186          1       SP      ENEAS FERREIRA CARNEIRO         PRONA   1.380.690
# 187          1       SP              ORESTES QUERCIA          PMDB     895.318
# 188          1       SP  ESPERIDIAO AMIN HELOU FILHO           PPR     247.152
# 189          1       SP      LEONEL DE MOURA BRIZOLA           PDT      67.747
# 190          1       SP         CARLOS ANTONIO GOMES           PRN      51.052
# 191          1       SP      HERNANI GOULART FORTUNA           PSC      43.547
# 192          1       GO    FERNANDO HENRIQUE CARDOSO          PSDB   1.171.550
# 193          1       GO    LUIZ INACIO LULA DA SILVA            PT     322.907
# 194          1       GO              ORESTES QUERCIA          PMDB     107.628
# 195          1       GO      ENEAS FERREIRA CARNEIRO         PRONA      93.314
# 196          1       GO  ESPERIDIAO AMIN HELOU FILHO           PPR      15.815
# 197          1       GO      LEONEL DE MOURA BRIZOLA           PDT      13.463
# 198          1       GO         CARLOS ANTONIO GOMES           PRN       6.918
# 199          1       GO      HERNANI GOULART FORTUNA           PSC       4.534
# 200          1       PI    FERNANDO HENRIQUE CARDOSO          PSDB     476.404
# 201          1       PI    LUIZ INACIO LULA DA SILVA            PT     296.077
# 202          1       PI              ORESTES QUERCIA          PMDB      82.867
# 203          1       PI      ENEAS FERREIRA CARNEIRO         PRONA      27.083
# 204          1       PI         CARLOS ANTONIO GOMES           PRN      20.614
# 205          1       PI      LEONEL DE MOURA BRIZOLA           PDT       9.257
# 206          1       PI  ESPERIDIAO AMIN HELOU FILHO           PPR       9.162
# 207          1       PI      HERNANI GOULART FORTUNA           PSC       3.460
# 208          1       TO    FERNANDO HENRIQUE CARDOSO          PSDB     234.699
# 209          1       TO    LUIZ INACIO LULA DA SILVA            PT      54.989
# 210          1       TO              ORESTES QUERCIA          PMDB      30.950
# 211          1       TO      ENEAS FERREIRA CARNEIRO         PRONA      12.566
# 212          1       TO      LEONEL DE MOURA BRIZOLA           PDT       3.847
# 213          1       TO  ESPERIDIAO AMIN HELOU FILHO           PPR       3.784
# 214          1       TO         CARLOS ANTONIO GOMES           PRN       3.039
# 215          1       TO      HERNANI GOULART FORTUNA           PSC       1.139
#
# [216 rows x 5 columns]

# %%
pd.to
